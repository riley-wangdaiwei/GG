# %%
import pandas as pd
import os
import numpy as np

shocks_data = {
    'company': ['Wave', 'Wave', 'Wave', 'Wave', 'Wave', 'Sendwave/Zepz'],
    'shock_name': [
        'wave_bceao_eme_license',
        'wave_staff_cut_15pct',
        'wave_debt_financing_91m',
        'wave_gambia_launch',
        'zepz_funding_267m',
        'wave_expansion_funding_137m'
    ],
    'shock_year': [2022, 2022, 2022, 2022, 2024, 2025],
    'shock_month': [4, 6, 7, 9, 10, 7],
    'shock_date': [
        14,
    np.nan,
        7,
        1,
        7,
        1
    ]
}

df_shocks_panel = pd.DataFrame(shocks_data)

target_dir = os.path.join('..', 'output')
os.makedirs(target_dir, exist_ok=True)

df_shocks_panel.to_csv(os.path.join(target_dir, 'shocks_panel_wave_sendwave_gambia.csv'), index=False)
